# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %%
df = pd.read_csv('/home/mitraa/Jupyter Notebook/covid-19_trendAnalysis/covid_19_clean_complete_2022.csv')

# %%
m = folium.Map()
df2 = df[df['Date']==min(df['Date'])]

# %%
df3 = df2.fillna(0)
df3
# Out:
#     Province/State        Country/Region        Lat        Long        Date  \
# 0                0           Afghanistan  33.939110   67.709953  2020-01-22
# 1                0               Albania  41.153300   20.168300  2020-01-22
# 2                0               Algeria  28.033900    1.659600  2020-01-22
# 3                0               Andorra  42.506300    1.521800  2020-01-22
# 4                0                Angola -11.202700   17.873900  2020-01-22
# ..             ...                   ...        ...         ...         ...
# 273              0    West Bank and Gaza  31.952200   35.233200  2020-01-22
# 274              0  Winter Olympics 2022  39.904200  116.407400  2020-01-22
# 275              0                 Yemen  15.552727   48.516388  2020-01-22
# 276              0                Zambia -13.133897   27.849332  2020-01-22
# 277              0              Zimbabwe -19.015438   29.154857  2020-01-22
#
# ...

# %%
for i in range(0,len(df3)):
    folium.Circle(location=[df3.iloc[i]['Lat'],df3.iloc[i]['Long']],
                 color='crimson',fill='crimson',
                 radius=int(df3.iloc[i]['Deaths'])).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
